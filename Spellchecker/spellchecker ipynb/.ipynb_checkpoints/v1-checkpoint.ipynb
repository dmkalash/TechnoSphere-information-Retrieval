# %%
fin = open('queries_all.txt')
i = 0

spell = 0

while True:
    s = fin.readline().split('\t')
    out = s[0]
    if len(s) > 1:
        out += ' !!!!!!!! ' + s[1]
    print(out , end='', sep='')
    i += 1
    if i > 45:
        break
# Out:
# видео секса смотреть бесплатно
# шоплифтеры казань
# платья 2016 фото новинки
# вк
# александр липовой
# Добро пожаловать в Одноклассники!
# секс анимированный
# Расписание электричек Чудово-1 (Московское). Маршруты пригородных поездов Чудово-1 (Московское)
# asus n46vz толщина dvd
# погода в скопине
# ютуб
# мелодрамы 2015 года новинки русские
# гугл
# где можно найти книгу советского горнолыжника тальянова
# способы получения информации экстрасенсами
# подвижный фалоимитатор
# оборудование для детской площадки
# рукопашный бой
# вертикальное озеленение
# ,
# участники вов поиск по фамилии архив и их награды
# порно мортал комбат
# ремонт меха
# умань
# рассказ инцест
# недашковская  артистка украины
# домашнее порно
# монитор
# Алиса
# платная рыбалка на мыльном
# лада
# экскаватор
# где купить фильм
# МАЛЮТИНА НАТАЛЬЯ АЛЕКСАНДРОВНА
# акт обследования жилищно бытовых условий семьи образец
# aoe игра
# екатерина горина фото
# enrique iglesias duele el corazon скачать бесплатно
# ...

# %%
fin = open('queries_all.txt')

i = 0
spell = 0

for s in fin:
    s = s.split('\t')
    out = s[0]
    if len(s) > 1:
        spell += 1
    i += 1

print(spell, i - spell)
# Out:
# 115232 1884768

# %%
import re
from tqdm.notebook import tqdm
import numpy as np

# %%
def get_part_letter_dict(origin, fixed):
    
    table = np.zeros((len(fixed) + 1, len(origin) + 1))
    table[0] = np.arange(len(origin) + 1)
    table[:, 0] = np.arange(len(fixed) + 1)
    
    for i in range( 1, len(fixed) + 1 ):
        for j in range( 1, len(origin) + 1 ):
            #print(len(origin), j - 1, len(fixed), i - 1, (origin[j - 1] != fixed[i - 1]))
            table[i, j] = min( table[i - 1, j] + 1,
                                table[i, j - 1] + 1,
                                table[i - 1, j - 1] + (origin[j - 1] != fixed[i - 1]) )
            
    part_letter_dict = dict()
    #one_letter_dict = dict()
    
    i, j = len(fixed), len(origin)
    while i != 0 and j != 0:
#         m = min( table[i - 1, j] + 1,
#                     table[i, j - 1] + 1,
#                     table[i - 1, j - 1] + (origin[j - 1] != fixed[i - 1]) )
        if table[i - 1, j - 1] + (origin[j - 1] != fixed[i - 1]) == table[i, j]:
            symb = origin[j - 1] + fixed[i - 1]
            part_letter_dict[symb] = part_letter_dict.get(symb, 0) + 1
            #one_letter_dict[origin[j - 1]] = one_letter_dict.get(origin[j - 1], 0) + 1
            i -= 1
            j -= 1
            
        elif table[i - 1, j] + 1 == table[i, j]:
            symb = '_' + fixed[i - 1]
            part_letter_dict[symb] = part_letter_dict.get(symb, 0) + 1
            #one_letter_dict[origin[j - 1]] = one_letter_dict.get(origin[j - 1], 0) + 1
            i -= 1
        else:
            symb = origin[j - 1] + '_'
            part_letter_dict[symb] = part_letter_dict.get(symb, 0) + 1
            #one_letter_dict['_'] = one_letter_dict.get('_', 0) + 1
            j -= 1
    
    while i != 0:
        symb = '_' + fixed[i - 1]
        part_letter_dict[symb] = part_letter_dict.get(symb, 0) + 1
        #one_letter_dict[origin[j - 1]] = one_letter_dict.get(origin[j - 1], 0) + 1
        i -= 1
        
    while j != 0:
        symb = origin[j - 1] + '_'
        part_letter_dict[symb] = part_letter_dict.get(symb, 0) + 1
        #one_letter_dict['_'] = one_letter_dict.get('_', 0) + 1
        j -= 1

    return part_letter_dict#, one_letter_dict

# %%
def prepare_query(query):
    tokens = re.findall(r'\w+', query)
    #tokens = re.findall(r'[A-Za-zа-яА-Я]+', pair[0])
            
    tokens = list( map(lambda s: s.lower(), tokens))
    return tokens

# %%
def get_words_prior_dict(fname='queries_all.txt'):
    with open(fname) as fin:
        words_dict = dict()
        bigramm_words_dict = dict()
        letter_dict = dict()
        #one_letter_dict = dict()
        hard_queries = []
        
        for i, line in tqdm(enumerate(fin)):
            pair = line.split('\t')
            if len(pair) > 1:
                pair[0], pair[1] = pair[1], pair[0]
            else:
                pair.append(pair[0])
                
            tokens = prepare_query( pair[0] )
            alpha_tokens = list(filter(lambda s: s.isalpha(), tokens))

            for token in set(alpha_tokens):
                words_dict[token] = words_dict.get(token, 0) + 1

            for w12 in zip(alpha_tokens, alpha_tokens[1:]):
                key = '_'.join(w12)
                bigramm_words_dict[key] = bigramm_words_dict.get(key, 0) + 1
                
            if len(pair) > 1:
                origin_tokens = prepare_query( pair[1] )
                if len(origin_tokens) != len(tokens):
                    hard_queries.append((i, line))
                    #print(i, origin_tokens, tokens, line)
                    continue
                
                for origin, fixed in zip(origin_tokens, tokens):
                    part_letter_dict = get_part_letter_dict(origin, fixed) # , part_one_letter_dict
                    for key in part_letter_dict:
                        letter_dict[key] = letter_dict.get(key, 0) + 1
#                     for key in one_letter_dict:
#                         one_letter_dict[key] = one_letter_dict.get(key, 0) + 1
                
#             if i > 100:
#                 break

        words_prior_dict = dict()
        for key in words_dict:
            words_prior_dict[key] = words_dict[key] / len(words_dict)
            
        for key in letter_dict:
            letter_dict[key] = letter_dict[key] / len(letter_dict) # one_letter_dict[key[0]]
            
        # smoothing mb:
        # words_prior_dict[key] = (words_prior_dict[key] + 1) / ( 2 * len(words_prior_dict))

        return words_dict, words_prior_dict, bigramm_words_dict, letter_dict, hard_queries

# %%
words_dict, words_prior_dict, bigramm_words_dict, letter_dict, hard_queries = get_words_prior_dict()

# %%
import pickle
with open('words_dict.pkl', 'wb') as output:
    pickle.dump(words_dict, output, pickle.HIGHEST_PROTOCOL)
    
with open('bigramm_words_dict.pkl', 'wb') as output:
    pickle.dump(bigramm_words_dict, output, pickle.HIGHEST_PROTOCOL)
    
with open('words_prior_dict.pkl', 'wb') as output:
    pickle.dump(words_prior_dict, output, pickle.HIGHEST_PROTOCOL)
    
with open('letter_dict.pkl', 'wb') as output:
    pickle.dump(letter_dict, output, pickle.HIGHEST_PROTOCOL)

with open('hard_queries.pkl', 'wb') as output:
    pickle.dump(hard_queries, output, pickle.HIGHEST_PROTOCOL)

# %%
# Out:
# {'смотреть': 108682,
#  'видео': 36699,
#  'бесплатно': 71115,
#  'секса': 449,
#  'казань': 891,
#  'шоплифтеры': 1,
#  'фото': 51771,
#  'новинки': 9164,
#  'платья': 2139,
#  'вк': 46214,
#  'александр': 1924,
#  'липовой': 130,
#  'пожаловать': 223,
#  'одноклассники': 10167,
#  'в': 173513,
#  'добро': 283,
#  'анимированный': 6,
#  'секс': 10998,
#  'поездов': 507,
#  'маршруты': 59,
#  'чудово': 12,
#  'расписание': 4543,
#  'московское': 85,
#  'электричек': 649,
#  'пригородных': 45,
#  'dvd': 267,
#  'asus': 279,
#  'толщина': 33,
#  'погода': 15828,
#  'скопине': 3,
#  'ютуб': 32542,
#  'мелодрамы': 1791,
#  'русские': 4749,
#  'года': 8523,
#  'гугл': 11660,
#  'книгу': 549,
#  'горнолыжника': 2,
#  'найти': 1869,
#  'советского': 214,
#  'тальянова': 1,
#  'где': 5933,
#  'можно': 5208,
#  'способы': 248,
#  'экстрасенсами': 2,
#  'информации': 156,
#  'получения': 106,
#  'фалоимитатор': 8,
#  'подвижный': 1,
#  'для': 77069,
#  'площадки': 129,
#  'детской': 450,
# ...

# %% [markdown]
# - Построить словарь слов из запросов по пробелам и знакам: там где нет исправлений - 0й индекс, иначе 1й - просто кол-во.
# - посмотреть на низкочастнотные слова, мб отсеять.
# - Отсеять спец символы и мб слова, где они посреди слова
# - посмотреть и мб отсеять слова и 1-2 букв
# - биграммы - делим на количество биграмм, слова - делим на количество слов.
# - words_prior_dict
# - biwords_prior_dict
#
#
# Модель ошибок:
# - строим dict биграмм исправлений(только для 1 символа пока что) через таблицу Левенштейна - количество исправлений каждой пары букв. Отдельная функция, которая return словарь биграммных исправлений. Берем его, обновляем общий словарь таких исправлений. Параллельно вести словарь количеств любых исправлений для каждой буквы, в самом конце поделить на эти числа. Это для коэффициентов.
# - Расстояние левенштейна. Можно класс с весами переходов + get_prior(). Веса переходов - на основе прошлого пункта.
# - вероятность: alpha^(-lev)
# - letter_dict, get_part_letter_dict, get_prior_letter_dict
# - class Levenstein
#
#
# - Модель языка(биграммная) - бьем на слова, считаем вероятности по формуле биграммной модели. Вероятности считать со сглаживанием Лапласа. Тоже dict пар последовательных слов с вероятностями
#
#
# - построить бор по списку слов. Класс, в котором хранится dict номер вершины:вершина. В вершине - номер вершины, список пар номер_сына, вес_сына, частота данного префикса(при построении высчитывается).
# - def build_trie -> dict, class Node
#
#
# - Генерация вариантов замены: нечеткий поиск в боре, обрезание по очереди с приоритетами до N объектов. Frequency - при построении бора считаем статистику слов. P(W|C) из модели ошибок. Считаем для каждого слова вес кандидатов, вес - сумма весов переходов в боре. Учитывать втч пропуск и вставку символов. Выкидать кандидатов, у которых вес < eps по итогу прохода через бор. Выкидывать по порогу отношения к весу макс кандидата
# - ...
# - #fuzzy_search
#
#
# - генерация кандидатов замены для запроса - оптимальный путь в графе. Умножать вес ребра на вес вершины в которую переходим, в конце еще вероятность последнего слова мб(как в формуле).
#
#
# - классификатор fix/none на фичах
#
#
# - ранжирование: пока сортируем по весу ошибки.
#
#
# - сделать итерации
#
#
# Далее:
# - другие типы ошибок
# - Бор + soundex можно для кандидатов
# - мб из одного запроса брать только множество слов, тк там могут они повторятся и это вроде портит стату.
# - мб вероятность в левенштейне по-другому считать
# - мб только по исправленным запросам биграммы букв считать
#
#
# + просмотреть еще раз конспект и прочекать разные дополнительные фичи

# %% [markdown]
# ['5', 'go', 'set', 'list'] ['5', 'go', 'setlist'] 5 go set list	5 go setlist
#
# ['64', 'x', '64', 'icons'] ['64', 'x64', 'icons'] 64 x 64 icons	64 x64 icons
#
# ['s', '84', 'site', 'io'] ['s84', 'site', 'io'] S 84 site:.io	S84 site:.io
#
# ['postcode', 'usa'] ['post', 'code', 'usa'] postcode usa	post code usa
#
# ['save', 'from', 'net'] ['savefrom', 'net'] save from net	savefrom net
#
# ['log', 'out', 'icloud', 'without', 'password', 'forum'] ['logout', 'icloud', 'without', 'password', 'forum'] log out icloud without password forum	logout icloud without password forum
#
# ['ad', 'block'] ['adblock'] ad block	adblock
#
# ['save', 'from', 'net'] ['savefrom', 'net'] save from net	savefrom net
#
# ['lm', '1036'] ['lm1036'] lm 1036	lm1036
#
# ['c', '91', 'site', 'at'] ['c91', 'site', 'at'] C 91 site:.at	C91 site:.at
#
# ['d', '91', 'site', 'be'] ['d91', 'site', 'be'] D 91 site:.be	D91 site:.be
#
# ['kb', '2919355'] ['kb2919355'] KB 2919355	KB2919355
#
# ['r', '91', 'site', 'li'] ['r91', 'site', 'li'] R 91 site:.li	R91 site:.li
#
# ['прохождениеthe', 'visitor', 'returns'] ['прохождение', 'the', 'visitor', 'returns'] ПрохождениеThe Visitor Returns	Прохождение The Visitor Returns
#
# ['gamedata', 'db', '7'] ['gamedata', 'db7'] gamedata.db 7	gamedata.db7
#
# ['e', '93', 'site', 'sa'] ['e93', 'site', 'sa'] E 93 site:.sa	E93 site:.sa
#
# ['c', 'cliner'] ['ccleaner'] c cliner	ccleaner
#
# ['text', 'uri', 'news', 'reporters', 'bugged'] ['texture', 'news', 'reporters', 'bugged'] text-uri news reporters bugged	texture news reporters bugged
#
# ['anti', 'bot', 'protection'] ['antibot', 'protection'] anti bot protection	antibot protection
#
# ['max', 'core'] ['maxcore'] max core	maxcore
#
# ['gj', 'fhs', 'd', 'минске', 'видео'] ['пожары', 'в', 'минске', 'видео'] gj;fhs d минске видео	пожары в минске видео
#
# ['gmail', 'log', 'in'] ['gmail', 'login'] gmail log in	gmail login
#
# ['open', 'box', 'file', 'type'] ['openbox', 'filetype'] open box file type	openbox filetype
#
# ['best', 'place', 'to', 'make', 'a', 'website', 'userid'] ['best', 'place', 'to', 'make', 'a', 'website', 'user', 'id'] best place to make a website userid=	best place to make a website user id=
#
# ['win7', 'тюненг'] ['win', '7', 'тюнинг'] win7 тюненг	win 7 тюнинг
#
# ['power', 'shell', 'для', 'wiondows', '8', 'установить'] ['powershell', 'для', 'windows', '8', 'установить'] power shell для wiondows 8 установить	powershell для windows 8 установить
#
# ['stoik', 'imaging', 'morpf', 'man'] ['stoik', 'imaging', 'morphman'] stoik imaging Morpf Man.	stoik imaging MorphMan.
#
# ['q', '99', 'site', 'nu'] ['q99', 'site', 'nu'] Q 99 site:.nu	Q99 site:.nu
#
# ['установить', 'baseerror', 'dll'] ['установить', 'base', 'error', 'dll'] установить baseerror.dll	установить base error.dll
#
# ['ulkan', 'run', 'time', 'libraries', '1', '0', '8', '1'] ['ulkan', 'runtime', 'libraries', '1', '0', '8', '1'] ulkan Run Time Libraries 1.0.8.1	ulkan RunTime Libraries 1.0.8.1
#
# ['advanced', 'system', 'care'] ['advanced', 'systemcare'] advanced system care	advanced systemcare
#
# ['driver', 'puck', 'solution'] ['driverpack', 'solution'] Driver Puck Solution.	DriverPack Solution.
#
# ['power', 'point', '2007'] ['powerpoint', '2007'] power point 2007	powerpoint 2007
#
# ['g', '78', 'site', 'se'] ['g78', 'site', 'se'] G 78 site:.se	G78 site:.se
#
# ['s', '78', 'site', 'se'] ['s78', 'site', 'se'] S 78 site:.se	S78 site:.se
#
# ['after', 'focus'] ['afterfocus'] after focus	afterfocus
#
# ['trust', 'installer'] ['trustedinstaller'] Trust installer	Trustedinstaller
#
# ['m', '80', 'site', 'im'] ['m', '80', 'site', 'i', 'm'] M 80 site:.im	M 80 site:.i m
#
# ['a', '81', 'site', 'ci'] ['a81', 'site', 'ci'] A 81 site:.ci	A81 site:.ci
#
# ['g', '82', 'site', 'ar'] ['g82', 'site', 'ar'] G 82 site:.ar	G82 site:.ar
#
# ['tekno', 'c', 'line'] ['tekno', 'cline'] tekno c line	tekno cline
#
# ['my', 'sql'] ['mysql'] my+sql	mysql
#
# ['beetel', 'router', 'login', 'username'] ['beetle', 'routerlogin', 'username'] beetel router login username	beetle routerlogin username
#
# ['power', 'off'] ['poweroff'] power off	poweroff
#
# ['ubuntu', 'принтсервер', 'windows', 'client'] ['ubuntu', 'принт', 'сервер', 'windows', 'client'] ubuntu принтсервер windows client	ubuntu принт сервер windows client
#
# ['web', 'log'] ['weblog'] Web-log)	Weblog)
#
# ['cfqn', 'tf', 'c'] ['сайт', 'еаэс'] cfqn tf'c	сайт еаэс
#
# ['brute', 'force', 'attack'] ['bruteforce', 'attack'] brute force attack	bruteforce attack
#
# ['r', '92', 'site', 'si'] ['r92', 'site', 'si'] R 92 site:.si	R92 site:.si
#
# ['книга', 'head', 'first', 'ajax'] ['книга', 'headfirst', 'ajax'] книга head first ajax	книга headfirst ajax
#
# ['google', 'for', 'start', 'page'] ['google', 'for', 'startpage'] google for start page	google for startpage
#
# ['a', '94', 'site', 'fi'] ['a94', 'site', 'fi'] A 94 site:.fi	A94 site:.fi
#
# ['visual', 'c', 'x', '32'] ['visual', 'c', 'x32'] Visual C++ x  32	Visual C++ x32
#
# ['a', '95', 'site', 'ad'] ['a95', 'site', 'ad'] A 95 site:.ad	A95 site:.ad
#
# ['wether', 'link'] ['weatherlink'] wether link	weatherlink
#
# ['j', '95', 'site', 'pf'] ['j95', 'site', 'pf'] J 95 site:.pf	J95 site:.pf
#
# ['g', '96', 'site', 'io'] ['g96', 'site', 'io'] G 96 site:.io	G96 site:.io
#
# ['m', '96', 'site', 'by'] ['m96', 'site', 'by'] M 96 site:.by	M96 site:.by
#
# ['system', 'cls', 'c'] ['system', 'clsc'] system cls c++	system clsc++
#
# ['make', 'a', 'webpage', 'phorum'] ['make', 'a', 'web', 'page', 'forum'] make a webpage /phorum/	make a web page /forum/
#
# ['inurl', 'sendmessage', 'asp', 'encompass'] ['inurl', 'send', 'message', 'asp', 'encompass'] inurl:/sendmessage.asp encompass	inurl:/send message.asp encompass
#
# ['auto', 'login'] ['autologin'] auto login	autologin
#
# ['i', 'launcher'] ['ilauncher'] i-launcher	ilauncher
#
# ['a', '98', 'site', 'at'] ['a98', 'site', 'at'] A 98 site:.at	A98 site:.at
#
# ['d', '98', 'site', 'eu'] ['d98', 'site', 'eu'] D 98 site:.eu	D98 site:.eu
#
# ['c', 'ne'] ['ютуб'] c.ne,	ютуб
#
# ['q', '99', 'site', 'ky'] ['q99', 'site', 'ky'] Q 99 site:.ky	Q99 site:.ky
#
# ['a', '100', 'site', 'do'] ['a100', 'site', 'do'] A 100 site:.do	A100 site:.do
#
# ['a', '100', 'site', 'do'] ['a100', 'site', 'do'] A 100 site:.do	A100 site:.do
#
# ['java', 'skript'] ['javascript'] java skript	javascript
#
# ['x', '80', 'site', 'ru'] ['x80', 'site', 'ru'] X 80 site:.ru	X80 site:.ru
#
# ['x', '80', 'site', 'ru'] ['x80', 'site', 'ru'] X 80 site:.ru	X80 site:.ru
#
# ['my', 'stat'] ['mystat'] my stat	mystat
#
# ['x', '86', 'site', 'kr'] ['x86', 'site', 'kr'] X 86 site:.kr	X86 site:.kr
#
# ['job', 'finder'] ['jobfinder'] job finder	jobfinder
#
# ['phpquery'] ['php', 'query'] phpQuery	php Query
#
# ['нфбкг'] ['ya', 'ru'] нфбкг	ya.ru
#
# ['fazza', 'tex'] ['fazzatex'] fazza tex	fazzatex
#
# ['расширениеspell', 'grammar', 'check'] ['расширение', 'speed', 'grammar', 'check'] расширениеspell grammar check	расширение speed grammar check
#
# ['r', '1800', 'hot', 'thread', 'with', 'no', 'new', 'posts'] ['r1800', 'hot', 'thread', 'with', 'no', 'new', 'posts'] R 1800 "Hot thread with no new posts"	R1800 "Hot thread with no new posts"
#
# ['ktc', 'bzyrbbpjkjnjqlj', 'lm'] ['лес', 'биянкиизолотойдождь'] ktc,bzyrbbpjkjnjqlj;lm	лес биянкиизолотойдождь
#
# ['report', 'viewer'] ['reportviewer'] Report Viewer	ReportViewer
#
# ['e', '93', 'site', 'sa'] ['e93', 'site', 'sa'] E 93 site:.sa	E93 site:.sa
#
# ['a', '94', 'site', 'fi'] ['a94', 'site', 'fi'] A 94 site:.fi	A94 site:.fi
#
# ['sound', 'max'] ['soundmax'] sound max	soundmax
#
# ['q', '94', 'site', 'ci'] ['q94', 'site', 'ci'] Q 94 site:.ci	Q94 site:.ci
#
# ['j', '95', 'site', 'org'] ['j95', 'site', 'org'] J 95 site:.org	J95 site:.org
#
# ['скачатьgulliver', 'the', 'resizing', 'mod'] ['скачать', 'gulliver', 'the', 'resizing', 'mod'] скачатьGulliver The Resizing Mod	скачать Gulliver The Resizing Mod
#
# ['abkmvb', 'j', 'k', 'db'] ['фильмы', 'о', 'любви'] abkmvb j k.,db	фильмы о любви
#
# ['tenda', 'a', '301', 'range'] ['tenda', 'a301', 'range'] tenda A 301 Range	tenda A301 Range
#
# ['не', 'устанавливаетс', 'я', 'google', 'chrome', 'на', 'windows', 'xp', '32', 'bit', 'service', 'pack', '1'] ['не', 'устанавливается', 'google', 'chrome', 'на', 'windows', 'xp', '32', 'bit', 'service', 'pack', '1'] не устанавливаетс я google chrome на windows xp 32 bit service pack 1	не устанавливается google chrome на windows xp 32 bit service pack 1
#
# ['log', 'in', 'gmail'] ['login', 'gmail'] log in gmail	login gmail
#
# ['скачать', 'steam', 'money', 'v2', '4', '6'] ['скачать', 'steammoney', 'v2', '4', '6'] скачать steam money v2.4.6	скачать steammoney v2.4.6
#
# ['ps', 'remout'] ['psremote'] ps remout	psremote
#
# ['pawer', 'point'] ['powerpoint'] pawer point	powerpoint
#
# ['c', '99', 'site', 'jm'] ['c99', 'site', 'jm'] C 99 site:.jm	C99 site:.jm
#
# ['q', '99', 'site', 'ky'] ['q99', 'site', 'ky'] Q 99 site:.ky	Q99 site:.ky
#
# ['get', 'style'] ['getstyle'] get style	getstyle
#
# ['free', 'space', 'management'] ['freespace', 'management'] free space management	freespace management
#
# ['excel', 'sum', 'product'] ['excel', 'sumproduct'] excel sum product	excel sumproduct
#
# ['s', '79', 'site', 'ie'] ['s79', 'site', 'ie'] S 79 site:.ie	S79 site:.ie
#
# ['s', '79', 'site', 'ie'] ['s79', 'site', 'ie'] S 79 site:.ie	S79 site:.ie
#
# ['imac', 'os', 'x', '10', '9', '4'] ['imac', 'os', 'x10', '9', '4'] imac os x 10/9/4/	imac os x10/9/4/
#
# ['s', '80', 'site', 'sa'] ['s80', 'site', 'sa'] S 80 site:.sa	S80 site:.sa
#
# ['m', '86', 'site', 'cf'] ['m86', 'site', 'cf'] M 86 site:.cf	M86 site:.cf
#
# ['id', 'port'] ['idport'] id port	idport
#
# ['sql', 'yog'] ['sqlyog'] sql yog	sqlyog
#
# ['s', '92', 'site', 'cf'] ['s92', 'site', 'cf'] S 92 site:.cf	S92 site:.cf
#
# ['mothercare', 'giraffe', 'travel', 'system'] ['mothercare', 'giraffe', 'travelsystem'] mothercare giraffe travel system	mothercare giraffe travelsystem
#
# ['nvidia', '64bit'] ['nvidia', '64', 'bit'] NVIDIA  64BIT	NVIDIA  64 BIT
#
# ['diamond', '777', 'com', 'privacy'] ['diamond777', 'com', 'privacy'] diamond-777 .com/privacy	diamond777 .com/privacy
#
# ['e', '94', 'site', 'info'] ['e94', 'site', 'info'] E 94 site:.info	E94 site:.info
#
# ['unity', 'get', 'unity'] ['unity', 'getunity'] Unity - Get Unity	Unity - GetUnity
#
# ['j', 'sl'] ['jsl'] [j€sl\	[jsl\
#
# ['q', '94', 'site', 'ci'] ['q94', 'site', 'ci'] Q 94 site:.ci	Q94 site:.ci
#
# ['add', 'rom', 'in', 'samsung', 'galaxy', 'gt', 's5', '282', 'youtube'] ['add', 'rom', 'in', 'samsung', 'galaxy', 'gt', 's5282', 'youtube'] add rom in samsung galaxy gt s5-282 -youtube	add rom in samsung galaxy gt s5282 -youtube
#
# ['medwell', 'publishing', 'home', 'page'] ['medwell', 'publishing', 'homepage'] Medwell Publishing - Home Page	Medwell Publishing - HomePage
#
# ['c', '97', 'site', 'am'] ['c97', 'site', 'am'] C 97 site:.am	C97 site:.am
#
# ['what', 'sap'] ['whatsapp'] What+sap	Whatsapp
#
# ['q', '97', 'site', 'ci'] ['q97', 'site', 'ci'] Q 97 site:.ci	Q97 site:.ci
#
# ['skytrax', 'log', 'on'] ['skytrax', 'logon'] skytrax log on	skytrax logon
#
# ['i', 'tao'] ['itao'] i tao	itao
#
# ['veral', 'test', 'microsoft', '10'] ['veraltest', 'microsoft', '10'] VERAL TEST MICROSOFT 10	VERALTEST MICROSOFT 10
#
# ['c', '99', 'site', 'jm'] ['c99', 'site', 'jm'] C 99 site:.jm	C99 site:.jm
#
# ['g', '99', 'site', 'ci'] ['g99', 'site', 'ci'] G 99 site:.ci	G99 site:.ci
#
# ['mutical', 'word'] ['mythicalworld'] MUTICAL WORD	MYTHICALWORLD
#
# ['https', '5vja90pjjd', 'execute', 'api', 'eu', 'west', '1', 'amazonaws', 'com', 'prod', 'id', 'njoolucws8fwsjup6ak7wkoly9y7fkavc4ce19', 'iduser_web', '5678670', 'wspostaba', 'simulatorbannerdynselligent', 'userid', '5678670'] ['https', '5vja90pjjd', 'execute', 'api', 'eu', 'west', '1', 'amazonaws', 'com', 'prod', 'id', 'njoolucws8fwsjup6ak7wkoly9y7fkavc4ce19', 'iduser_web', '5678670', 'wspostaba', 'simulatorbannerdynselligent', 'user', 'id', '5678670'] https://5vja90pjjd.execute-api.eu-west-1.amazonaws.com/prod?ID=nJooluCws8fwSjUp6AK7WkOLy9y7FkAvc4cE19&iduser_web=5678670 /wspostaba/SimulatorBannerDynSelligent/userId/5678670	https://5vja90pjjd.execute-api.eu-west-1.amazonaws.com/prod?ID=nJooluCws8fwSjUp6AK7WkOLy9y7FkAvc4cE19&iduser_web=5678670 /wspostaba/SimulatorBannerDynSelligent/user Id/5678670
#
# ['gt', 'j', '1007', 'j', 'tv'] ['пежо', '1007', 'объем'] GT;J 1007 J,]TV	ПЕжО 1007 ОбъЕМ
#
# ['turbo', 'install', 'on', 'bertone'] ['turboinstall', 'on', 'bertone'] turbo install on bertone	turboinstall on bertone
#
# ['t', 'ff', 'd', 'ff', 'rrrdf'] ['е', 'а', 'а', 'в', 'аа', 'ккква'] T FF D FF RRRDF	Е А а В АА КККВА
#
# ['java', 'script', 'var', 'h', 'document', 'getelementsbyclassname', 'post_actions', 'var', 'i', '0', 'function', 'del_wall', 'var', 'fn_str', 'h', 'i', 'getelementsbytagname', 'div', '0', 'onclick', 'tostring', 'var', 'fn_arr_1', 'fn_str', 'split', 'var', 'fn_arr_2', 'fn_arr_1', '1', 'split', 'eval', 'fn_arr_2', '0', 'if', 'i', 'h', 'length', 'clearinterval', 'int_id', 'else', 'i', 'var', 'int_id', 'setinterval', 'del_wall', '500'] ['javascript', 'var', 'h', 'document', 'getelementsbyclassname', 'post_actions', 'var', 'i', '0', 'function', 'del_wall', 'var', 'fn_str', 'h', 'i', 'getelementsbytagname', 'div', '0', 'onclick', 'tostring', 'var', 'fn_arr_1', 'fn_str', 'split', 'var', 'fn_arr_2', 'fn_arr_1', '1', 'split', 'eval', 'fn_arr_2', '0', 'if', 'i', 'h', 'length', 'clearinterval', 'int_id', 'else', 'i', 'var', 'int_id', 'setinterval', 'del_wall', '500'] java***script:var h = document.getElementsByClassName("post_actions");var i = 0;function del_wall(){var fn_str = h[i].getElementsByTagName("div")[0].onclick.toString();var fn_arr_1 = fn_str.split("{");var fn_arr_2 = fn_arr_1[1].split(";");eval(fn_arr_2[0]);if(i == h.length){clearInterval(int_id)}else{i++}};var int_id=setInterval(del_wall,500);	javascript:var h = document.getElementsByClassName("post_actions");var i = 0;function del_wall(){var fn_str = h[i].getElementsByTagName("div")[0].onclick.toString();var fn_arr_1 = fn_str.split("{");var fn_arr_2 = fn_arr_1[1].split(";");eval(fn_arr_2[0]);if(i == h.length){clearInterval(int_id)}else{i++}};var int_id=setInterval(del_wall,500);
#
# ['mode', 'm'] ['modem'] Mode-M	ModeM
#
# ['s', '78', 'site', 'se'] ['s78', 'site', 'se'] S 78 site:.se	S78 site:.se
#
# ['s', '78', 'site', 'se'] ['s78', 'site', 'se'] S 78 site:.se	S78 site:.se
#
# ['скачать', 'ad', 'block', 'для', 'fairfox'] ['скачать', 'adblock', 'для', 'firefox'] скачать ad block  для fairfox	скачать adblock  для firefox
#
# ['m', '80', 'site', 'im'] ['m', '80', 'site', 'i', 'm'] M 80 site:.im	M 80 site:.i m
#
# ['x', '80', 'site', 'ru'] ['x80', 'site', 'ru'] X 80 site:.ru	X80 site:.ru
#
# ['inurl', 'tabid', 'userid'] ['inurl', 'tabid', 'user', 'id'] inurl:tabid+userid	inurl:tabid+user id
#
# ['s', '84', 'site', 'io'] ['s84', 'site', 'io'] S 84 site:.io	S84 site:.io
#
# ['game', 'date', 'a', 'live'] ['game', 'date', 'alive'] game date a live	game date alive
#
# ['нфбкг'] ['ya', 'ru'] нфбкг	ya.ru
#
# ['gt', 'j'] ['пежо'] gt;j	пежо
#
# ['buton', 'bass'] ['buttonbass'] buton bass	buttonbass
#
# ['bar', 'code', 'generator', 'excel'] ['barcode', 'generator', 'excel'] bar code generator excel	barcode generator excel
#
# ['socks', '24'] ['socks24'] socks 24	socks24
#
# ['e', '94', 'site', 'se'] ['e94', 'site', 'se'] E 94 site:.se	E94 site:.se
#
# ['instal', 'pack'] ['installpack'] instal pack	installpack
#
# ['g', '96', 'site', 'af'] ['g96', 'site', 'af'] G 96 site:.af	G96 site:.af
#
# ['g', '96', 'site', 'ci'] ['g96', 'site', 'ci'] G 96 site:.ci	G96 site:.ci
#
# ['apple', '44'] ['apple44'] apple 44	apple44
#
# ['s', '3', 'queries', 'css', 'processed', 'in', 'copyright', '2005', 'xhtml', 'mij'] ['s3', 'queries', 'css', 'processed', 'in', 'copyright', '2005', 'xhtml', 'mij'] "s 3 queries" "css Processed in" "CopyRight 2005" xhtml mij	"s3 queries" "css Processed in" "CopyRight 2005" xhtml mij
#
# ['tr2', 'tr2', 'открыть'] ['tr2', 'tr', '2', 'открыть'] "TR2" (.tr2) открыть	"TR2" (.tr 2) открыть
#
# ['m', '99', 'site', 'info'] ['m99', 'site', 'info'] M 99 site:.info	M99 site:.info
#
# ['apm', 's'] ['arms'] apm s	arms
#
# ['binary', 'mag'] ['binarymag'] binary-mag	binarymag
#
# ['start', 'bloue', 'stacks'] ['start', 'bluestacks'] Start Bloue Stacks	Start BlueStacks
#
# ['j', '101', 'site', 'mo'] ['j101', 'site', 'mo'] J 101 site:.mo	J101 site:.mo
#
# ['search', 's', 'search'] ['searchs', 'search'] SEARCH S SEARCH	SEARCHS SEARCH
#
# ['screen', 'stream', 'mirroring', 'j', 'pjh'] ['screen', 'stream', 'mirroring', 'обзор'] Screen Stream Mirroring J,PJH	Screen Stream Mirroring ОбЗОР
#
# ['rc', 'b', 'bwjybcn'] ['эксгибиционист'] 'rc[b,bwjybcn	эксгибиционист
#
# ['php5', 'парсинг', 'xml'] ['php', '5', 'парсинг', 'xml'] php5 парсинг xml	php 5 парсинг xml
#
# ['s', '79', 'site', 'ie'] ['s79', 'site', 'ie'] S 79 site:.ie	S79 site:.ie
#
# ['dns', 'ip'] ['dnsip'] dns-ip	dnsip
#
# ['general', 'motors', 'датчик', 'а', 'map'] ['general', 'motors', 'датчика', 'map'] General Motors Датчик а-map	General Motors Датчика-map
#
# ['send', 'message'] ['sendmessage'] Send Message	SendMessage
#
# ['windows', 'vista', 'c', 'jhrf'] ['windows', 'vista', 'сборка'] windows vista c,jhrf	windows vista сборка
#
# ['inurl', 'sendmessage', 'asp', 'touches'] ['inurl', 'send', 'message', 'asp', 'touches'] inurl:/sendmessage.asp touches	inurl:/send message.asp touches
#
# ['error', 'title', 'tr', 'td', 'id', 'infoiconalign', 'width', '60', 'align', 'left', 'valign', 'top', 'rowspan', '2', 'img', 'src', 'res', 'ieframe', 'dll', 'info_48', 'png', 'id', 'infoicon', 'alt', 'info', 'icon', 'td', 'td', 'id', 'maintitlealign', 'valign', 'middle', 'align', 'left', 'width', 'h1', 'id', 'maintitle', 'navigation', 'to', 'the', 'webpage', 'was', 'canceled', 'h1', 'td', 'tr', 'tr'] ['error', 'title', 'tr', 'td', 'id', 'infoiconalign', 'width', '60', 'align', 'left', 'valign', 'top', 'rowspan', '2', 'img', 'src', 'res', 'ieframe', 'dll', 'info_48', 'png', 'id', 'infoicon', 'alt', 'infoicon', 'td', 'td', 'id', 'maintitlealign', 'valign', 'middle', 'align', 'left', 'width', 'h1', 'id', 'maintitle', 'navigation', 'to', 'the', 'webpage', 'was', 'canceled', 'h1', 'td', 'tr', 'tr'] -- Error title -->              <tr>                  <td id="infoIconAlign" width="60" align="left" valign="top" rowspan="2">                      <img src="res://ieframe.dll/info_48.png" id="infoIcon" alt="Info icon">                  </td>                  <td id="mainTitleAlign" valign="middle" align="left" width="*">                      <h1 id="mainTitle">Navigation to the webpage was canceled</h1>                  </td>              </tr>                    <tr>                  <	-- Error title -->             <tr>                 <td id="infoIconAlign" width="60" align="left" valign="top" rowspan="2">                     <img src="res://ieframe.dll/info_48.png" id="infoIcon" alt="Infoicon">                 </td>                 <td id="mainTitleAlign" valign="middle" align="left" width="*">                     <h1 id="mainTitle">Navigation to the webpage was canceled</h1>                 </td>             </tr>                <tr>                 <
#
# ['dowlond', 'check', 'point'] ['download', 'checkpoint'] dowlond check point	download checkpoint
#
# ['save', 'from'] ['savefrom'] save from	savefrom
#
# ['card', 'print'] ['cardprint'] card print	cardprint
#
# ['a', '94', 'site', 'fi'] ['a94', 'site', 'fi'] A 94 site:.fi	A94 site:.fi
#
# ['e', '94', 'site', 'info'] ['e94', 'site', 'info'] E 94 site:.info	E94 site:.info
#
# ['s', '94', 'site', 'ai'] ['s94', 'site', 'ai'] S 94 site:.ai	S94 site:.ai
#
# ['e', 'mail', 'address', 'and', 'user', 'name', 'can', 'be', 'saved', 'in', 'the', 'preferences'] ['e', 'mail', 'address', 'and', 'username', 'can', 'be', 'saved', 'in', 'the', 'preferences'] "E-mail address and user name can be saved in the Preferences"	"E-mail address and username can be saved in the Preferences"
#
# ['r', 'tp'] ['без'] ,r tp	без
#
# ['register', 'net', 'us'] ['register', 'natus'] register net us	register natus
#
# ['one', 'lan'] ['oneland'] one-lan	oneland
#
# ['get', 'files'] ['getfiles'] get files	getfiles
#
# ['cs', '5', 'audio', 'delay'] ['cs5', 'audio', 'delay'] cs-5 audio delay	cs5 audio delay
#
# ['lenstra', 's', 'ecm'] ['linestra', 'secm'] lenstra's ecm	linestra'secm
#
# ['wheres', 'my', 'cellphone'] ['where', 's', 'my', 'cell', 'phone'] Wheres My Cellphone?	Where s My Cell phone?
#
# ['lesson', '1', 'java', 'script'] ['lesson', '1', 'javascript'] Lesson 1 - Java Script	Lesson 1 - JavaScript
#
# ['random', 'chest'] ['randomchest'] random chest	randomchest
#
# ['m', '80', 'site', 'im'] ['m', '80', 'site', 'i', 'm'] M 80 site:.im	M 80 site:.i m
#
# ['ktc', 'bzyrbbpjkjnjqlj', 'lm'] ['лес', 'биянкиизолотойдождь'] ktc,bzyrbbpjkjnjqlj;lm	лес биянкиизолотойдождь
#
# ['new', 'tab'] ['newtab'] New Tab	NewTab
#
# ['run', 'time', 'error', '1004'] ['runtime', 'error', '1004'] run-time error 1004	runtime error 1004
#
# ['g', '91', 'site', 'ie'] ['g91', 'site', 'ie'] G 91 site:.ie	G91 site:.ie
#
# ['how', 'to', 'insert', 'a', 'photo', 'in', 'a', 'frame', 'in', 'the', 'time', 'line', 'of', 'power', 'director'] ['how', 'to', 'insert', 'a', 'photo', 'in', 'a', 'frame', 'in', 'the', 'timeline', 'of', 'power', 'director'] how to insert a photo in a frame in the time line of power director	how to insert a photo in a frame in the timeline of power director
#
# ['i', 'want', 'to', 'create', 'website', 'userid'] ['i', 'want', 'to', 'create', 'website', 'user', 'id'] i want to create website userid=	i want to create website user id=
#
# ['r', '1800', 'hot', 'thread', 'with', 'no', 'new', 'posts'] ['r1800', 'hot', 'thread', 'with', 'no', 'new', 'posts'] R 1800 "Hot thread with no new posts"	R1800 "Hot thread with no new posts"
#
# ['word', 'press', 'plugin'] ['wordpress', 'plugin'] word press plugin	wordpress plugin
#
# ['crypto', 'vpn', 'gui'] ['cryptovpn', 'gui'] crypto vpn gui	cryptovpn gui
#
# ['alert', 'box', 'twitch', 'alerts'] ['alert', 'box', 'twitchalerts'] Alert Box / Twitch Alerts	Alert Box / TwitchAlerts
#
# ['card', 'print'] ['cardprint'] card print	cardprint
#
# ['english', 'grammar', 'the', 'words', 'which', 'can', 'not', 'be', 'deleted', 'in', 'the', 'sentence'] ['english', 'grammar', 'the', 'words', 'which', 'cannot', 'be', 'deleted', 'in', 'the', 'sentence'] English Grammar The words which can not be deleted in the sentence	English Grammar The words which cannot be deleted in the sentence
#
# ['b', '95', 'site', 'hr'] ['b95', 'site', 'hr'] B 95 site:.hr	B95 site:.hr
#
# ['invalid', 'e', 'mail', 'address', 'and', 'or', 'password'] ['invalid', 'email', 'address', 'and', 'or', 'password'] Invalid e-mail address and/or password.	Invalid email address and/or password.
#
# ['make', 'a', 'webpage', 'phorum'] ['make', 'a', 'web', 'page', 'forum'] make a webpage /phorum/	make a web page /forum/
#
# ['img', 'class', 'chem', 'icon', 'src', 'static', 'img', 'chemistry', 'att', 'png'] ['img', 'class', 'chemicon', 'src', 'static', 'img', 'chemistry', 'att', 'png'] <img class="chem-icon" src="/static/img/chemistry/att.png">	<img class="chemicon" src="/static/img/chemistry/att.png">
#
# ['cool', 'player', 'на', 'андроид'] ['coolplayer', 'на', 'андроид'] cool player на андроид	coolplayer на андроид
#
# ['скачать', 'password', 'box', 'для', 'firefox'] ['скачать', 'passwordbox', 'для', 'firefox'] скачать password box для firefox	скачать passwordbox для firefox
#
# ['fh', 'tk'] ['барбелл'] ,fh,tk	барбелл
#
# ['скачатьmsvcr120', 'dll', 'x86'] ['скачать', 'msvcr120', 'dll', 'x86'] скачатьMSVCR120.dll x86	скачать MSVCR120.dll x86
#
# ['get', 'style'] ['getstyle'] get style	getstyle
#
# ['g', '78', 'site', 'se'] ['g78', 'site', 'se'] G 78 site:.se	G78 site:.se
#
# ['ktc', 'bzyrbbpjkjnjqlj', 'lm'] ['лес', 'биянкиизолотойдождь'] ktc,bzyrbbpjkjnjqlj;lm	лес биянкиизолотойдождь
#
# ['planet', 'base', 'пароль'] ['planetbase', 'пароль'] planet base пароль	planetbase пароль
#
# ['m', '86', 'site', 'cf'] ['m86', 'site', 'cf'] M 86 site:.cf	M86 site:.cf
#
# ['m', '86', 'site', 'cf'] ['m86', 'site', 'cf'] M 86 site:.cf	M86 site:.cf
#
# ['microsoft', 'tool', 'kit'] ['microsoft', 'toolkit'] microsoft tool kit	microsoft toolkit
#
# ['unity', '3d', 'play', 'animation', 'on', 'trigger', 'enter'] ['unity3d', 'play', 'animation', 'on', 'trigger', 'enter'] unity 3d play animation on trigger enter	unity3d play animation on trigger enter
#
# ['site', 'in', 'create', 'an', 'account', 'forgot', 'your', 'username', 'forgot', 'your', 'password', 'log', 'in', 'login', 'form', 'remember', 'me'] ['site', 'in', 'create', 'an', 'account', 'forgot', 'your', 'username', 'forgot', 'your', 'password', 'login', 'loginform', 'remember', 'me'] site:.in "Create an account" "Forgot your username?" "Forgot your password?" "Log in" "Login Form" "Remember Me"	site:.in "Create an account" "Forgot your username?" "Forgot your password?" "Login" "LoginForm" "Remember Me"
#
# ['net', 'time', '242'] ['nettime', '242'] Net Time#242	NetTime#242
#
# ['c', '91', 'site', 'at'] ['c91', 'site', 'at'] C 91 site:.at	C91 site:.at
#
# ['c', '94', 'site', 'nu'] ['c94', 'site', 'nu'] C 94 site:.nu	C94 site:.nu
#
# ['e', '94', 'site', 'info'] ['e94', 'site', 'info'] E 94 site:.info	E94 site:.info
#
# ['10', 'kb', '09'] ['10', 'kb09'] 10 kb 09	10 kb09
#
# ['make', 'a', 'webpage', 'phorum'] ['make', 'a', 'web', 'page', 'forum'] make a webpage /phorum/	make a web page /forum/
#
# ['app', 'down', 'loader', 'sites'] ['appdown', 'loader', 'sites'] app down;loader sites	appdown;loader sites
#
# ['sw', 'db'] ['swdb'] sw-db	swdb
#
# ['q', '97', 'site', 'ci'] ['q97', 'site', 'ci'] Q 97 site:.ci	Q97 site:.ci
#
# ['test', '2', 'testing', 'through', 'out', 'the', 'software', 'life', 'cycle'] ['test', '2', 'testing', 'throughout', 'the', 'software', 'life', 'cycle'] Test 2. Testing through out the Software life cycle	Test 2. Testing throughout the Software life cycle
#
# ['n3'] ['n', '3'] .n3,	.n 3,
#
# ['t', 'file'] ['tfile'] t-file	tfile
#
# ['скачать', 'usbboot', 'installer'] ['скачать', 'usb', 'boot', 'installer'] скачать USBboot Installer++	скачать USB boot Installer++
#
# ['dns', 'ip'] ['dnsip'] dns-ip	dnsip
#
# ['n', 'dbx'] ['ndbx'] n dbx	ndbx
#
# ['d', '101', 'site', 'bg'] ['d101', 'site', 'bg'] D 101 site:.bg	D101 site:.bg
#
# ['s', '78', 'site', 'se'] ['s78', 'site', 'se'] S 78 site:.se	S78 site:.se
#
# ['s', '79', 'site', 'ie'] ['s79', 'site', 'ie'] S 79 site:.ie	S79 site:.ie
#
# ['g', '82', 'site', 'ar'] ['g82', 'site', 'ar'] G 82 site:.ar	G82 site:.ar
#
# ['r', '85', 'site', 'ag'] ['r85', 'site', 'ag'] R 85 site:.ag	R85 site:.ag
#
# ['sip', 'trunk', 'cucm', 'free', 'pbx'] ['sip', 'trunk', 'cucm', 'freepbx'] sip trunk cucm free pbx	sip trunk cucm freepbx
